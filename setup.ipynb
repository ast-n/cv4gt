# %% [markdown]
# # Setup Notebook
# This notebook will download the necessary dataset and models for the CV4GT project.

# %% [markdown]
# ## 0 - Installing required dependencies

# %%
# %pip install roboflow ultralytics huggingface_hub
# Out:
# Requirement already satisfied: roboflow in c:\python\python311\lib\site-packages (1.1.61)
# Requirement already satisfied: ultralytics in c:\python\python311\lib\site-packages (8.3.108)
# Requirement already satisfied: huggingface_hub in c:\python\python311\lib\site-packages (0.30.2)
# Requirement already satisfied: certifi in c:\python\python311\lib\site-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: idna==3.7 in c:\python\python311\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\python\python311\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python\python311\lib\site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in c:\python\python311\lib\site-packages (from roboflow) (3.9.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\python\python311\lib\site-packages (from roboflow) (1.24.1)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\python\python311\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\python\python311\lib\site-packages (from roboflow) (11.2.1)
# Requirement already satisfied: pillow-heif>=0.18.0 in c:\python\python311\lib\site-packages (from roboflow) (0.22.0)
# Requirement already satisfied: python-dateutil in c:\python\python311\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in c:\python\python311\lib\site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: requests in c:\python\python311\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\python\python311\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\python\python311\lib\site-packages (from roboflow) (1.26.13)
# Requirement already satisfied: tqdm>=4.41.0 in c:\python\python311\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\python\python311\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\python\python311\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\python\python311\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\python\python311\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: scipy>=1.4.1 in c:\python\python311\lib\site-packages (from ultralytics) (1.14.0)
# Requirement already satisfied: torch>=1.8.0 in c:\python\python311\lib\site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\python\python311\lib\site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: psutil in c:\users\jerome liao\appdata\roaming\python\python311\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\python\python311\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\python\python311\lib\site-packages (from ultralytics) (1.5.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\python\python311\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\python\python311\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: filelock in c:\python\python311\lib\site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\python\python311\lib\site-packages (from huggingface_hub) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in c:\python\python311\lib\site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\python\python311\lib\site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\python311\lib\site-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\python311\lib\site-packages (from matplotlib->roboflow) (4.53.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python\python311\lib\site-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python311\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python\python311\lib\site-packages (from requests->roboflow) (2.1.1)
# Requirement already satisfied: networkx in c:\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in c:\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python\python311\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\jerome liao\appdata\roaming\python\python311\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python\python311\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1 - Download dataset from Roboflow

# %%
import getpass
from roboflow import Roboflow

api_key = getpass.getpass("Enter your Roboflow API key: \n")
rf = Roboflow(api_key)
project = rf.workspace("cos40005capstone").project("cv4gt-data")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in cv4gt-data-1 to yolov8:: 100%|██████████| 13884/13884 [00:02<00:00, 5727.16it/s]
# Extracting Dataset Version Zip to cv4gt-data-1 in yolov8:: 100%|██████████| 464/464 [00:00<00:00, 1537.55it/s]
# optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.

# %% [markdown]
# ## 2 - Download Pre-Trained Models from HuggingFace

# %%
import os
from huggingface_hub import hf_hub_download

# Create models directory if it doesn't exist
os.makedirs("models", exist_ok=True)

# Download the models
repo_id = "ast-n/cv4gt"
models = [
    "YOLOv8-cv4gt-bad-dataset_epochs500.pt",
    "YOLOv8-cv4gt-data-11-04_10e"
]

for model_name in models:
    try:
        model_path = hf_hub_download(repo_id=repo_id, filename=model_name, local_dir="models")
        print(f"Downloaded {model_name} to {model_path}")
    except Exception as e:
        print(f"Error downloading {model_name}: {e}")
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# Error downloading YOLOv8-cv4gt-bad-dataset_epochs500.pt: An error happened while trying to locate the file on the Hub and we cannot find the requested files in the local cache. Please check your connection and try again or make sure your Internet connection is on.
# Error downloading YOLOv8-cv4gt-data-11-04_10e: An error happened while trying to locate the file on the Hub and we cannot find the requested files in the local cache. Please check your connection and try again or make sure your Internet connection is on.

# %% [markdown]
# ## 3 - Test model loading

# %%
from ultralytics import YOLO

# Try and load model

model_path = "models/YOLOv8-cv4gt-bad-dataset_epochs500.pt"

if os.path.exists(model_path):
    print(f"Model loaded successfully from {model_path}")
else:
    print(f"Model not found at {model_path}. Try again")
# Out:
# Model loaded successfully from models/YOLOv8-cv4gt-bad-dataset_epochs500.pt

# %% [markdown]
# # TO add, model uploading
